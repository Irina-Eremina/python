# %%
print ('hi')
# Out:
# hi

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/df3.csv')
len (df)
# Out:
# 500

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/df3.csv')
headers =df.columns
print(headers)
# Out:
# Index(['weekday', 'produced', 'defective'], dtype='object')

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/df3.csv')
df.head()
# Out:
#        weekday  produced  defective
# 0     1.Monday        73          7
# 1    2.Tuesday        75         10
# 2  3.Wednesday        86          7
# 3   4.Thursday        64          7
# 4     5.Friday        70          6

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/df3.csv')
df.plot.scatter (x='produced', y='defective', c='r')

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/df3.csv')
df ['produced']. plot.hist()

# %%
df ['produced']. plot.hist(edgecolor='k')

# %%
df[['produced', 'weekday']].boxplot(by='weekday', grid=False)

# %%
df['defective'].plot.kde()

# %%
df['defective'].plot.kde(linestyle= '--')

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/df3.csv')
df_1=df.loc[:30, ['produced', 'defective']]
df_1.plot(kind='area', stacked=False, color=['steelblue','peru'])

# %%
import matplotlib.pyplot as plt
df_1=df.loc[:30, ['produced', 'defective']]
df_1.plot(kind='area', stacked=False, color=['steelblue','peru'])
plt.legend (loc='center left', bbox_to_anchor=(1, 0.5))

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/df3.csv')
print (df)
# Out:
#          weekday  produced  defective
# 0       1.Monday        73          7
# 1      2.Tuesday        75         10
# 2    3.Wednesday        86          7
# 3     4.Thursday        64          7
# 4       5.Friday        70          6
# ..           ...       ...        ...
# 495     1.Monday        62          8
# 496    2.Tuesday        73         10
# 497  3.Wednesday        79          7
# 498   4.Thursday        78          6
# 499     5.Friday        55          5
#
# [500 rows x 3 columns]
